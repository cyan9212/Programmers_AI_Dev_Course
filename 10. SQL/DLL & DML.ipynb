# %% [markdown]
# 주피터 SQL 엔진 설정

# %%
# %load_ext sql

# %%
# %sql postgresql://guest:Guest1234@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# 'Connected: guest@dev'

# %% [markdown]
# 다양한 SELECT 실행해보기

# %%
# %%sql
#
# SELECT *
# FROM raw_data.user_session_channel
# LIMIT 20;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 20 rows affected.
# [(1491, '00029153d12ae1c9abe59c17ff2e0895', 'Organic'),
#  (59, '0002ac0d783338cfeab0b2bdbd872cda', 'Naver'),
#  (117, '0006246bee639c7a7b11a08e34dd3cc6', 'Youtube'),
#  (572, '0006dd05ea1e999ddaa041a7091b7b36', 'Organic'),
#  (935, '0007cda84fafdcf42f96c4f4adb7f8ce', 'Google'),
#  (1363, '000a91f3e374e6147d58ed1814247508', 'Naver'),
#  (780, '000c076c390a4c357313fca29e390ece', 'Naver'),
#  (1917, '000d0c74074191add6f22e0004db8f76', 'Organic'),
#  (1357, '000d54aadcedee0739d39127955f2cdb', 'Instagram'),
#  (1247, '000dd3543ac84d906eae52e7c779bb2a', 'Naver'),
#  (887, '000e82a96e908e73372bed4e5cb98096', 'Facebook'),
#  (2728, '00146eefb7aa8cc45a7f321ff2b523ee', 'Naver'),
#  (1037, '001b8e3cf76f4e64cbe5be9882db4aa0', 'Instagram'),
#  (2037, '001c10d28e514c413b461eae83abdb4b', 'Facebook'),
#  (1473, '001c728a3046207c685f7f478f4bb41b', 'Google'),
#  (197, '001d3439223b7bb23ed89b9c8890d096', 'Naver'),
#  (2081, '001d47bd412e7c944a91f0e63fafa70c', 'Youtube'),
#  (278, '001fca6b304504b620c727b498b2d814', 'Naver'),
#  (971, '0020194058e082c8b253eadc35c9ba31', 'Facebook'),
#  (1967, '0025ad7a491d38ca9bb71732255dc01d', 'Naver')]

# %%
# %%sql
#
# SELECT userId, sessionId, channel
# FROM raw_data.user_session_channel;

# %%
# %%sql
#
# SELECT *
# FROM raw_data.user_session_channel
# LIMIT 10;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(1651, '0004289ee1c7b8b08c77e19878106ae3', 'Organic'),
#  (1197, '00053f5e11d1fe4e49a221165b39abc9', 'Facebook'),
#  (1401, '00056c20eb5a029583db75506953f1d9', 'Facebook'),
#  (1399, '00063cb5da1826febf178b669eea3250', 'Facebook'),
#  (1667, '000958fdaefe0dd06f5d7c4e4a5f28d1', 'Instagram'),
#  (468, '000a3f777828d2cdbee98887561aa130', 'Facebook'),
#  (1563, '000cb7efa8a05429dd5309b4bea2eb0c', 'Naver'),
#  (711, '00106ac9184e7d54b570d0f0cb0c38b2', 'Organic'),
#  (473, '0011df6282fe8cf78feeab676fbc3c27', 'Naver'),
#  (420, '00126b47d5502dfb7d01f750ad23d813', 'Facebook')]

# %%
# %%sql
#
# SELECT DISTINCT channel                      -- 유일한 채널 이름을 알고 싶은 경우
# FROM raw_data.user_session_channel;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 6 rows affected.
# [('Naver',),
#  ('Facebook',),
#  ('Youtube',),
#  ('Instagram',),
#  ('Organic',),
#  ('Google',)]

# %%
# %%sql
#
# SELECT channel, COUNT(1)                    -- 채널별 카운트를 하고 싶은 경우. COUNT 함수!!
# FROM raw_data.user_session_channel
# GROUP BY 1;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 6 rows affected.
# [('Facebook', 16791),
#  ('Google', 16982),
#  ('Instagram', 16831),
#  ('Naver', 16921),
#  ('Organic', 16904),
#  ('Youtube', 17091)]

# %%
# %%sql
#
# SELECT COUNT(1)                    -- 테이블의 모든 레코드 수 카운트. COUNT(*). 하나의 레코드
# FROM raw_data.user_session_channel;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(101520,)]

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM raw_data.user_session_channel
# WHERE channel = 'Facebook';
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(16791,)]

# %%
# %%sql
#
# SELECT
#   channel,
#   CASE
#     WHEN channel in ('Facebook', 'Instagram') THEN 'Social-Media'
#     WHEN channel in ('Google', 'Naver') THEN 'Search-Engine'
#     ELSE 'Something-Else'
# END channel_type
# FROM raw_data.user_session_channel
# LIMIT 100;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 100 rows affected.
# [('Naver', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Facebook', 'Social-Media'),
#  ('Naver', 'Search-Engine'),
#  ('Youtube', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Instagram', 'Social-Media'),
#  ('Organic', 'Something-Else'),
#  ('Google', 'Search-Engine'),
#  ('Youtube', 'Something-Else'),
#  ('Naver', 'Search-Engine'),
#  ('Instagram', 'Social-Media'),
#  ('Youtube', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Google', 'Search-Engine'),
#  ('Google', 'Search-Engine'),
#  ('Organic', 'Something-Else'),
#  ('Youtube', 'Something-Else'),
#  ('Google', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Facebook', 'Social-Media'),
#  ('Youtube', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Google', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Naver', 'Search-Engine'),
#  ('Youtube', 'Something-Else'),
#  ('Youtube', 'Something-Else'),
#  ('Google', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Instagram', 'Social-Media'),
#  ('Google', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Naver', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Google', 'Search-Engine'),
#  ('Instagram', 'Social-Media'),
#  ('Google', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Instagram', 'Social-Media'),
#  ('Facebook', 'Social-Media'),
#  ('Naver', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Instagram', 'Social-Media'),
#  ('Youtube', 'Something-Else'),
#  ('Google', 'Search-Engine'),
#  ('Youtube', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Instagram', 'Social-Media'),
#  ('Naver', 'Search-Engine'),
#  ('Organic', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Youtube', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Naver', 'Search-Engine'),
#  ('Google', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Organic', 'Something-Else'),
#  ('Youtube', 'Something-Else'),
#  ('Instagram', 'Social-Media'),
#  ('Naver', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Naver', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Google', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Youtube', 'Something-Else'),
#  ('Google', 'Search-Engine'),
#  ('Google', 'Search-Engine'),
#  ('Organic', 'Something-Else'),
#  ('Naver', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Youtube', 'Something-Else'),
#  ('Facebook', 'Social-Media'),
#  ('Organic', 'Something-Else'),
#  ('Youtube', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Naver', 'Search-Engine'),
#  ('Youtube', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Facebook', 'Social-Media'),
#  ('Naver', 'Search-Engine'),
#  ('Organic', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Facebook', 'Social-Media'),
#  ('Youtube', 'Something-Else'),
#  ('Organic', 'Something-Else'),
#  ('Google', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Naver', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Organic', 'Something-Else'),
#  ('Instagram', 'Social-Media'),
#  ('Google', 'Search-Engine'),
#  ('Google', 'Search-Engine'),
#  ('Facebook', 'Social-Media'),
#  ('Naver', 'Search-Engine')]

# %%
# %%sql
#
# SELECT COUNT(1)
# FROM raw_data.user_session_channel
# WHERE channel in ('Google','Facebook');
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(33773,)]

# %%
# %%sql
#
# SELECT DISTINCT channel
# FROM raw_data.user_session_channel
# WHERE channel ILIKE '%o%';
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 4 rows affected.
# [('Organic',), ('Google',), ('Facebook',), ('Youtube',)]

# %%
# %%sql
#
# SELECT
#     LEN(channel),
#     UPPER(channel),
#     LOWER(channel),
#     LEFT(channel, 4)
# FROM raw_data.user_session_channel
# LIMIT 100;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 100 rows affected.
# [(5, 'NAVER', 'naver', 'Nave'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (7, 'YOUTUBE', 'youtube', 'Yout'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (5, 'NAVER', 'naver', 'Nave'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (7, 'ORGANIC', 'organic', 'Orga'),
#  (9, 'INSTAGRAM', 'instagram', 'Inst'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (6, 'GOOGLE', 'google', 'Goog'),
#  (8, 'FACEBOOK', 'facebook', 'Face'),
#  (5, 'NAVER', 'naver', 'Nave')]

# %% [markdown]
# CREATE TABLE raw_data.count_test (
#     value int
# );
#
# INSERT INTO raw_data.count_test VALUES (NULL), (1), (1), (0), (0), (4), (3);

# %%
# %%sql
#
# SELECT
#     COUNT(1) count_1,
#     COUNT(0) count_0,
#     COUNT(NULL) as count_null,
#     COUNT(value) count_value,
#     COUNT(DISTINCT value) count_distinct_value
# FROM raw_data.count_test;

# %%
# %%sql
#
# SELECT 0 + NULL, 0 - NULL, 0 * NULL, 0/NULL

# %%
# %%sql
#
# SELECT
#     GETDATE(),
#     CONVERT_TIMEZONE('America/Los_Angeles', GETDATE());

# %%
# %%sql
#
# SELECT 1/2, 1/2::float;

# %% [markdown]
# 판다스와 연동하는 방법

# %%
result = %sql SELECT * FROM raw_data.user_session_channel
df = result.DataFrame()
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 101520 rows affected.

# %%
df.head()
# Out:
#    userid                         sessionid    channel
# 0    1651  0004289ee1c7b8b08c77e19878106ae3    Organic
# 1    1197  00053f5e11d1fe4e49a221165b39abc9   Facebook
# 2    1401  00056c20eb5a029583db75506953f1d9   Facebook
# 3    1399  00063cb5da1826febf178b669eea3250   Facebook
# 4    1667  000958fdaefe0dd06f5d7c4e4a5f28d1  Instagram

# %%
df.groupby(["channel"]).size()
# Out:
# channel
# Facebook     16791
# Google       16982
# Instagram    16831
# Naver        16921
# Organic      16904
# Youtube      17091
# dtype: int64

# %%
df.groupby(["channel"])["sessionid"].count()
# Out:
# channel
# Facebook     16791
# Google       16982
# Instagram    16831
# Naver        16921
# Organic      16904
# Youtube      17091
# Name: sessionid, dtype: int64
